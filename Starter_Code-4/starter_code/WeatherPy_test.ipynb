# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# %pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.13.1-cp312-cp312-macosx_12_0_arm64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scipy) (1.26.4)
# Downloading scipy-1.13.1-cp312-cp312-macosx_12_0_arm64.whl (30.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.4/30.4 MB 68.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: scipy
# Successfully installed scipy-1.13.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/wenlirui/Library/Python/3.12/lib/python/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /Users/wenlirui/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.2-cp312-cp312-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 39.6 MB/s eta 0:00:00a 0:00:01
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 42.6 MB/s eta 0:00:00
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 38.9 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.2 pytz-2024.1 tzdata-2024.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.53.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.2/162.2 kB 3.7 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Collecting numpy>=1.23 (from matplotlib)
#   Downloading numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /Users/wenlirui/Library/Python/3.12/lib/python/site-packages (from matplotlib) (24.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.3.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/wenlirui/Library/Python/3.12/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/wenlirui/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.0-cp312-cp312-macosx_11_0_arm64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 23.9 MB/s eta 0:00:00a 0:00:01
# Downloading contourpy-1.2.1-cp312-cp312-macosx_11_0_arm64.whl (245 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 26.8 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.0-cp312-cp312-macosx_11_0_arm64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 56.4 MB/s eta 0:00:0000:01
# Downloading kiwisolver-1.4.5-cp312-cp312-macosx_11_0_arm64.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 7.8 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl (13.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 81.9 MB/s eta 0:00:00a 0:00:01
# Downloading pillow-10.3.0-cp312-cp312-macosx_11_0_arm64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 61.7 MB/s eta 0:00:00a 0:00:01
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 12.2 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.0 kiwisolver-1.4.5 matplotlib-3.9.0 numpy-1.26.4 pillow-10.3.0 pyparsing-3.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install citipy
# Out:
# Collecting citipy
#   Using cached citipy-0.0.6.tar.gz (675 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting kdtree>=0.12 (from citipy)
#   Using cached kdtree-0.16-py2.py3-none-any.whl.metadata (1.3 kB)
# Using cached kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Building wheels for collected packages: citipy
#   Building wheel for citipy (pyproject.toml) ... done
#   Created wheel for citipy: filename=citipy-0.0.6-py3-none-any.whl size=675966 sha256=0bf46610c2b5f19fa08efc7fc3ee34b03cdd2cc776ae046c3996a297b4fac308
#   Stored in directory: /Users/wenlirui/Library/Caches/pip/wheels/e9/27/5f/7defd70aaec29af33fe5e2110843e14dcfc44cba710a0dd957
# Successfully built citipy
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.6 kdtree-0.16
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key 

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
import time
import datetime

# %%
from pathlib import Path
import os

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 588

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
city_url = f"{url}appid={weather_api_key}&units={units}&q="
for i, city in enumerate(cities):
    city_weather = requests.get(city_url + city.replace(" ","+")).json()
print(city_weather)
# Out:
# {'coord': {'lon': 29.5448, 'lat': -31.6229}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 16.45, 'feels_like': 15.98, 'temp_min': 16.45, 'temp_max': 16.45, 'pressure': 1033, 'humidity': 70, 'sea_level': 1033, 'grnd_level': 1032}, 'visibility': 10000, 'wind': {'speed': 2.86, 'deg': 51, 'gust': 3.51}, 'clouds': {'all': 71}, 'dt': 1717863618, 'sys': {'country': 'ZA', 'sunrise': 1717822615, 'sunset': 1717859111}, 'timezone': 7200, 'id': 964408, 'name': "Port Saint John's", 'cod': 200}

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    
    
    city_url = f"{url}appid={weather_api_key}&units={units}&q="
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url + city.replace(" ","+")).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds =city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = datetime.datetime.fromtimestamp(city_weather["dt"])

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | praia da vitoria
# Processing Record 2 of Set 1 | grytviken
# Processing Record 3 of Set 1 | adamstown
# Processing Record 4 of Set 1 | san felipe
# Processing Record 5 of Set 1 | lander
# Processing Record 6 of Set 1 | puerto natales
# Processing Record 7 of Set 1 | ribadesella
# Processing Record 8 of Set 1 | wynyard
# Processing Record 9 of Set 1 | port-aux-francais
# Processing Record 10 of Set 1 | naryn
# Processing Record 11 of Set 1 | tazovsky
# Processing Record 12 of Set 1 | nadym
# Processing Record 13 of Set 1 | hamilton
# Processing Record 14 of Set 1 | fuvahmulah
# City not found. Skipping...
# Processing Record 15 of Set 1 | waitangi
# Processing Record 16 of Set 1 | donggang
# Processing Record 17 of Set 1 | ayr
# Processing Record 18 of Set 1 | tiksi
# Processing Record 19 of Set 1 | longyearbyen
# Processing Record 20 of Set 1 | la passe
# Processing Record 21 of Set 1 | qaqortoq
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | stanley
# Processing Record 24 of Set 1 | ribeira grande
# Processing Record 25 of Set 1 | enewetak
# Processing Record 26 of Set 1 | ta`u
# Processing Record 27 of Set 1 | masterton
# Processing Record 28 of Set 1 | elmendorf air force base
# City not found. Skipping...
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | kapa'a
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | invercargill
# Processing Record 33 of Set 1 | waingapu
# Processing Record 34 of Set 1 | sigayevo
# Processing Record 35 of Set 1 | papatowai
# Processing Record 36 of Set 1 | guerrero negro
# Processing Record 37 of Set 1 | hammerfest
# Processing Record 38 of Set 1 | den burg
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | badger
# Processing Record 41 of Set 1 | udachny
# Processing Record 42 of Set 1 | joroinen
# Processing Record 43 of Set 1 | mugia
# Processing Record 44 of Set 1 | blackmans bay
# Processing Record 45 of Set 1 | vuktyl
# Processing Record 46 of Set 1 | suntar
# Processing Record 47 of Set 1 | kuruman
# Processing Record 48 of Set 1 | pangody
# Processing Record 49 of Set 1 | northam
# Processing Record 50 of Set 1 | gao
# Processing Record 0 of Set 2 | carnarvon
# Processing Record 1 of Set 2 | cabedelo
# Processing Record 2 of Set 2 | vorgashor
# Processing Record 3 of Set 2 | hawaiian paradise park
# Processing Record 4 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 5 of Set 2 | whitehorse
# Processing Record 6 of Set 2 | perevolotskiy
# Processing Record 7 of Set 2 | cambria
# Processing Record 8 of Set 2 | touros
# Processing Record 9 of Set 2 | shohimardon
# Processing Record 10 of Set 2 | crane
# Processing Record 11 of Set 2 | chonchi
# Processing Record 12 of Set 2 | samarinda
# Processing Record 13 of Set 2 | vilyuchinsk
# Processing Record 14 of Set 2 | keflavik
# Processing Record 15 of Set 2 | la ronge
# Processing Record 16 of Set 2 | mar del plata
# Processing Record 17 of Set 2 | labuan
# Processing Record 18 of Set 2 | kenai
# Processing Record 19 of Set 2 | kununurra
# Processing Record 20 of Set 2 | umluj
# Processing Record 21 of Set 2 | zakamensk
# Processing Record 22 of Set 2 | chardara
# Processing Record 23 of Set 2 | greenland
# Processing Record 24 of Set 2 | jamestown
# Processing Record 25 of Set 2 | murzuq
# Processing Record 26 of Set 2 | port lincoln
# Processing Record 27 of Set 2 | arkalyk
# Processing Record 28 of Set 2 | qui nhon
# Processing Record 29 of Set 2 | wailua homesteads
# Processing Record 30 of Set 2 | hoxtolgay
# City not found. Skipping...
# Processing Record 31 of Set 2 | port mathurin
# Processing Record 32 of Set 2 | port elizabeth
# Processing Record 33 of Set 2 | baiquan
# Processing Record 34 of Set 2 | jabat
# Processing Record 35 of Set 2 | coxim
# Processing Record 36 of Set 2 | iskateley
# Processing Record 37 of Set 2 | puerto ayora
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | yenangyaung
# Processing Record 40 of Set 2 | bethel
# Processing Record 41 of Set 2 | cooper's town
# Processing Record 42 of Set 2 | rock springs
# Processing Record 43 of Set 2 | bucerias
# Processing Record 44 of Set 2 | tsiombe
# Processing Record 45 of Set 2 | sabang
# Processing Record 46 of Set 2 | simplicio mendes
# Processing Record 47 of Set 2 | west island
# Processing Record 48 of Set 2 | dunedin
# Processing Record 49 of Set 2 | east london
# Processing Record 0 of Set 3 | kargasok
# Processing Record 1 of Set 3 | kirakira
# Processing Record 2 of Set 3 | college
# Processing Record 3 of Set 3 | mount isa
# Processing Record 4 of Set 3 | bilibino
# Processing Record 5 of Set 3 | targuist
# Processing Record 6 of Set 3 | shofirkon shahri
# City not found. Skipping...
# Processing Record 7 of Set 3 | edinburgh of the seven seas
# Processing Record 8 of Set 3 | san antonio de pale
# Processing Record 9 of Set 3 | nar'yan-mar
# Processing Record 10 of Set 3 | nyurba
# Processing Record 11 of Set 3 | albany
# Processing Record 12 of Set 3 | shizuishan
# Processing Record 13 of Set 3 | pyapon
# Processing Record 14 of Set 3 | hauterive
# Processing Record 15 of Set 3 | luau
# Processing Record 16 of Set 3 | san marcos
# Processing Record 17 of Set 3 | yaren
# Processing Record 18 of Set 3 | kapuskasing
# Processing Record 19 of Set 3 | anadyr
# Processing Record 20 of Set 3 | san patricio
# Processing Record 21 of Set 3 | dzilam gonzalez
# Processing Record 22 of Set 3 | nowshahr
# Processing Record 23 of Set 3 | tongren
# Processing Record 24 of Set 3 | saipan
# Processing Record 25 of Set 3 | luderitz
# Processing Record 26 of Set 3 | shakawe
# Processing Record 27 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 28 of Set 3 | markovo
# Processing Record 29 of Set 3 | isafjordur
# Processing Record 30 of Set 3 | zamania
# Processing Record 31 of Set 3 | minas de marcona
# Processing Record 32 of Set 3 | carnaiba
# Processing Record 33 of Set 3 | sanya
# Processing Record 34 of Set 3 | itoman
# Processing Record 35 of Set 3 | garoua boulai
# Processing Record 36 of Set 3 | grantsville
# Processing Record 37 of Set 3 | leava
# Processing Record 38 of Set 3 | ilulissat
# Processing Record 39 of Set 3 | ciudad lazaro cardenas
# Processing Record 40 of Set 3 | tolanaro
# Processing Record 41 of Set 3 | avarua
# Processing Record 42 of Set 3 | tranovaho
# City not found. Skipping...
# Processing Record 43 of Set 3 | roxas
# Processing Record 44 of Set 3 | salvador
# Processing Record 45 of Set 3 | maintirano
# Processing Record 46 of Set 3 | fale old settlement
# Processing Record 47 of Set 3 | berdigestyakh
# Processing Record 48 of Set 3 | general conesa
# Processing Record 49 of Set 3 | margaret river
# Processing Record 0 of Set 4 | kangdong-up
# Processing Record 1 of Set 4 | grafton
# Processing Record 2 of Set 4 | aasiaat
# Processing Record 3 of Set 4 | pasighat
# Processing Record 4 of Set 4 | brisas de zicatela
# Processing Record 5 of Set 4 | urumqi
# Processing Record 6 of Set 4 | san jose village
# City not found. Skipping...
# Processing Record 7 of Set 4 | kingston
# Processing Record 8 of Set 4 | fortuna
# Processing Record 9 of Set 4 | novyy urengoy
# Processing Record 10 of Set 4 | suva
# Processing Record 11 of Set 4 | cable beach
# City not found. Skipping...
# Processing Record 12 of Set 4 | wajir
# Processing Record 13 of Set 4 | san jose del guaviare
# Processing Record 14 of Set 4 | nguekhokh
# Processing Record 15 of Set 4 | narasannapeta
# Processing Record 16 of Set 4 | gamba
# Processing Record 17 of Set 4 | hilo
# Processing Record 18 of Set 4 | rosarito
# Processing Record 19 of Set 4 | quellon
# Processing Record 20 of Set 4 | zouerate
# Processing Record 21 of Set 4 | kristiansund
# Processing Record 22 of Set 4 | sinabang
# Processing Record 23 of Set 4 | cole harbour
# Processing Record 24 of Set 4 | smithers
# Processing Record 25 of Set 4 | dhuusamarreeb
# Processing Record 26 of Set 4 | colonia
# Processing Record 27 of Set 4 | valle de la pascua
# Processing Record 28 of Set 4 | prien
# Processing Record 29 of Set 4 | qamdo
# Processing Record 30 of Set 4 | tura
# Processing Record 31 of Set 4 | san juan de miraflores
# Processing Record 32 of Set 4 | monticello
# Processing Record 33 of Set 4 | onega
# Processing Record 34 of Set 4 | malayer
# Processing Record 35 of Set 4 | tamanrasset
# Processing Record 36 of Set 4 | vilyuysk
# Processing Record 37 of Set 4 | gordes
# Processing Record 38 of Set 4 | toliara
# Processing Record 39 of Set 4 | lincheng
# Processing Record 40 of Set 4 | sokode
# Processing Record 41 of Set 4 | preston
# Processing Record 42 of Set 4 | watampone
# Processing Record 43 of Set 4 | agat village
# Processing Record 44 of Set 4 | chapada dos guimaraes
# Processing Record 45 of Set 4 | alice springs
# Processing Record 46 of Set 4 | rokytne
# Processing Record 47 of Set 4 | hirara
# Processing Record 48 of Set 4 | batang
# Processing Record 49 of Set 4 | bikenibeu village
# Processing Record 0 of Set 5 | creel
# Processing Record 1 of Set 5 | kinkala
# Processing Record 2 of Set 5 | hasaki
# Processing Record 3 of Set 5 | nova vicosa
# Processing Record 4 of Set 5 | mahajanga
# Processing Record 5 of Set 5 | lihue
# Processing Record 6 of Set 5 | karaj
# Processing Record 7 of Set 5 | kodiak
# Processing Record 8 of Set 5 | olonkinbyen
# Processing Record 9 of Set 5 | coquimbo
# Processing Record 10 of Set 5 | thompson
# Processing Record 11 of Set 5 | fedorovskiy
# Processing Record 12 of Set 5 | nova sintra
# Processing Record 13 of Set 5 | zyryanskoye
# Processing Record 14 of Set 5 | kruisfontein
# Processing Record 15 of Set 5 | tarauaca
# Processing Record 16 of Set 5 | islamorada
# Processing Record 17 of Set 5 | chapadinha
# Processing Record 18 of Set 5 | khandyga
# Processing Record 19 of Set 5 | kanniyakumari
# Processing Record 20 of Set 5 | vila velha
# Processing Record 21 of Set 5 | bocana de paiwas
# Processing Record 22 of Set 5 | atafu village
# Processing Record 23 of Set 5 | veraval
# Processing Record 24 of Set 5 | bredasdorp
# Processing Record 25 of Set 5 | mount pleasant
# Processing Record 26 of Set 5 | whitby
# Processing Record 27 of Set 5 | tazacorte
# Processing Record 28 of Set 5 | haiku-pauwela
# Processing Record 29 of Set 5 | kuanda
# Processing Record 30 of Set 5 | amga
# Processing Record 31 of Set 5 | lerwick
# Processing Record 32 of Set 5 | yoloten
# Processing Record 33 of Set 5 | tahe
# Processing Record 34 of Set 5 | sungjibaegam
# Processing Record 35 of Set 5 | aripuana
# Processing Record 36 of Set 5 | labytnangi
# Processing Record 37 of Set 5 | pottstown
# Processing Record 38 of Set 5 | iqaluit
# Processing Record 39 of Set 5 | hermanus
# Processing Record 40 of Set 5 | cabo san lucas
# Processing Record 41 of Set 5 | runing
# Processing Record 42 of Set 5 | farasan
# Processing Record 43 of Set 5 | west bay
# Processing Record 44 of Set 5 | hachinohe
# Processing Record 45 of Set 5 | moyo
# Processing Record 46 of Set 5 | nizhnesortymskiy
# Processing Record 47 of Set 5 | sibolga
# Processing Record 48 of Set 5 | lancaster
# Processing Record 49 of Set 5 | popondetta
# Processing Record 0 of Set 6 | ust-nera
# Processing Record 1 of Set 6 | alofi
# Processing Record 2 of Set 6 | manavalakurichi
# Processing Record 3 of Set 6 | georgetown
# Processing Record 4 of Set 6 | igarka
# Processing Record 5 of Set 6 | doctor arroyo
# Processing Record 6 of Set 6 | gaspe
# Processing Record 7 of Set 6 | arraial do cabo
# Processing Record 8 of Set 6 | sansepolcro
# Processing Record 9 of Set 6 | constantia
# Processing Record 10 of Set 6 | kayanza
# Processing Record 11 of Set 6 | arta
# Processing Record 12 of Set 6 | mount pearl
# Processing Record 13 of Set 6 | butterworth
# Processing Record 14 of Set 6 | kapoeta
# Processing Record 15 of Set 6 | tommot
# Processing Record 16 of Set 6 | nizhneangarsk
# Processing Record 17 of Set 6 | woolgoolga
# Processing Record 18 of Set 6 | recani
# Processing Record 19 of Set 6 | st. john's
# Processing Record 20 of Set 6 | kovalam
# Processing Record 21 of Set 6 | elliot lake
# Processing Record 22 of Set 6 | hobyo
# Processing Record 23 of Set 6 | kulia village
# City not found. Skipping...
# Processing Record 24 of Set 6 | ghanzi
# Processing Record 25 of Set 6 | dutsen wai
# Processing Record 26 of Set 6 | polyarnyy
# Processing Record 27 of Set 6 | ketchikan
# Processing Record 28 of Set 6 | karaton
# Processing Record 29 of Set 6 | yomju-up
# Processing Record 30 of Set 6 | kavieng
# Processing Record 31 of Set 6 | khanty-mansiysk
# Processing Record 32 of Set 6 | saint-denis
# Processing Record 33 of Set 6 | oranjemund
# Processing Record 34 of Set 6 | katsuura
# Processing Record 35 of Set 6 | uttar char fasson
# Processing Record 36 of Set 6 | sanctuary point
# Processing Record 37 of Set 6 | tir pul
# Processing Record 38 of Set 6 | warmbad
# Processing Record 39 of Set 6 | holualoa
# Processing Record 40 of Set 6 | cidreira
# Processing Record 41 of Set 6 | wuhai
# Processing Record 42 of Set 6 | sterling
# Processing Record 43 of Set 6 | rongelap
# Processing Record 44 of Set 6 | ironwood
# Processing Record 45 of Set 6 | nahiyat ash shinafiyah
# Processing Record 46 of Set 6 | giyani
# Processing Record 47 of Set 6 | santa cruz
# Processing Record 48 of Set 6 | xinmin
# Processing Record 49 of Set 6 | remire-montjoly
# Processing Record 0 of Set 7 | gaalkacyo
# Processing Record 1 of Set 7 | port-vila
# Processing Record 2 of Set 7 | talnakh
# Processing Record 3 of Set 7 | broome
# Processing Record 4 of Set 7 | broken hill
# Processing Record 5 of Set 7 | luis correia
# Processing Record 6 of Set 7 | vadso
# Processing Record 7 of Set 7 | sanming
# Processing Record 8 of Set 7 | shirpur
# Processing Record 9 of Set 7 | bayan nur
# City not found. Skipping...
# Processing Record 10 of Set 7 | fort bragg
# Processing Record 11 of Set 7 | pisco
# Processing Record 12 of Set 7 | kiunga
# Processing Record 13 of Set 7 | glendive
# Processing Record 14 of Set 7 | saldanha
# Processing Record 15 of Set 7 | nuevo casas grandes
# Processing Record 16 of Set 7 | piton saint-leu
# Processing Record 17 of Set 7 | geraldton
# Processing Record 18 of Set 7 | lompoc
# Processing Record 19 of Set 7 | bocas del toro
# Processing Record 20 of Set 7 | ortakoy
# Processing Record 21 of Set 7 | severo-yeniseyskiy
# Processing Record 22 of Set 7 | saint-pierre
# Processing Record 23 of Set 7 | shimoda
# Processing Record 24 of Set 7 | saint-philippe
# Processing Record 25 of Set 7 | petawawa
# Processing Record 26 of Set 7 | jackson
# Processing Record 27 of Set 7 | praia
# Processing Record 28 of Set 7 | mata-utu
# Processing Record 29 of Set 7 | hadibu
# Processing Record 30 of Set 7 | east end
# Processing Record 31 of Set 7 | carmen
# Processing Record 32 of Set 7 | lorengau
# Processing Record 33 of Set 7 | barbacoas
# Processing Record 34 of Set 7 | hamamatsu
# Processing Record 35 of Set 7 | noumea
# Processing Record 36 of Set 7 | abepura
# Processing Record 37 of Set 7 | kyshtovka
# Processing Record 38 of Set 7 | zungeru
# Processing Record 39 of Set 7 | ak'ordat
# Processing Record 40 of Set 7 | dwarka
# Processing Record 41 of Set 7 | pajara
# Processing Record 42 of Set 7 | n'zeto
# Processing Record 43 of Set 7 | jaisalmer
# Processing Record 44 of Set 7 | blatna
# Processing Record 45 of Set 7 | bengkulu
# Processing Record 46 of Set 7 | pajapan
# Processing Record 47 of Set 7 | ola
# Processing Record 48 of Set 7 | stornoway
# Processing Record 49 of Set 7 | dudinka
# Processing Record 0 of Set 8 | gadzhiyevo
# Processing Record 1 of Set 8 | labrador city
# Processing Record 2 of Set 8 | san pedro
# Processing Record 3 of Set 8 | cargados carajos
# City not found. Skipping...
# Processing Record 4 of Set 8 | taulaga
# Processing Record 5 of Set 8 | turpan
# Processing Record 6 of Set 8 | ifanadiana
# Processing Record 7 of Set 8 | kayenta
# Processing Record 8 of Set 8 | launceston
# Processing Record 9 of Set 8 | senador guiomard
# Processing Record 10 of Set 8 | upata
# Processing Record 11 of Set 8 | mukah
# City not found. Skipping...
# Processing Record 12 of Set 8 | ancud
# Processing Record 13 of Set 8 | mitsamiouli
# Processing Record 14 of Set 8 | nyons
# Processing Record 15 of Set 8 | urangan
# Processing Record 16 of Set 8 | paita
# Processing Record 17 of Set 8 | afaahiti
# Processing Record 18 of Set 8 | selfoss
# Processing Record 19 of Set 8 | aweil
# Processing Record 20 of Set 8 | uturoa
# Processing Record 21 of Set 8 | pacasmayo
# Processing Record 22 of Set 8 | toga village
# City not found. Skipping...
# Processing Record 23 of Set 8 | letlhakane
# Processing Record 24 of Set 8 | midvagur
# Processing Record 25 of Set 8 | coahuayana de hidalgo
# Processing Record 26 of Set 8 | la mitra
# Processing Record 27 of Set 8 | ulsteinvik
# Processing Record 28 of Set 8 | al kharijah
# Processing Record 29 of Set 8 | paceco
# Processing Record 30 of Set 8 | malakal
# Processing Record 31 of Set 8 | oppdal
# Processing Record 32 of Set 8 | aykhal
# Processing Record 33 of Set 8 | wichita falls
# Processing Record 34 of Set 8 | sitka
# Processing Record 35 of Set 8 | chertkovo
# Processing Record 36 of Set 8 | merizo village
# Processing Record 37 of Set 8 | dickinson
# Processing Record 38 of Set 8 | brokopondo
# Processing Record 39 of Set 8 | medicine hat
# Processing Record 40 of Set 8 | alesund
# Processing Record 41 of Set 8 | boa vista
# Processing Record 42 of Set 8 | ulaangom
# Processing Record 43 of Set 8 | nuku'alofa
# Processing Record 44 of Set 8 | turtas
# Processing Record 45 of Set 8 | port moresby
# Processing Record 46 of Set 8 | adiake
# Processing Record 47 of Set 8 | araguaina
# Processing Record 48 of Set 8 | linkoping
# Processing Record 49 of Set 8 | argostolion
# Processing Record 0 of Set 9 | papao
# Processing Record 1 of Set 9 | al azraq ash shamali
# City not found. Skipping...
# Processing Record 2 of Set 9 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 3 of Set 9 | paka
# Processing Record 4 of Set 9 | port glaud
# City not found. Skipping...
# Processing Record 5 of Set 9 | minot air force base
# Processing Record 6 of Set 9 | ladario
# Processing Record 7 of Set 9 | howrah
# Processing Record 8 of Set 9 | arraias
# Processing Record 9 of Set 9 | pinotepa nacional
# Processing Record 10 of Set 9 | kill devil hills
# Processing Record 11 of Set 9 | ryotsu-minato
# Processing Record 12 of Set 9 | sooke
# Processing Record 13 of Set 9 | namibe
# Processing Record 14 of Set 9 | kurchum
# Processing Record 15 of Set 9 | zheleznogorsk-ilimskiy
# Processing Record 16 of Set 9 | san giovanni valdarno
# Processing Record 17 of Set 9 | talcahuano
# Processing Record 18 of Set 9 | martignas-sur-jalle
# Processing Record 19 of Set 9 | belmonte
# Processing Record 20 of Set 9 | istgah-e rah ahan-e garmsar
# Processing Record 21 of Set 9 | cowra
# Processing Record 22 of Set 9 | mombetsu
# Processing Record 23 of Set 9 | lata
# Processing Record 24 of Set 9 | reichenbach/vogtland
# Processing Record 25 of Set 9 | ahau
# City not found. Skipping...
# Processing Record 26 of Set 9 | princeville
# Processing Record 27 of Set 9 | yinchuan
# Processing Record 28 of Set 9 | bedi
# Processing Record 29 of Set 9 | shumikha
# Processing Record 30 of Set 9 | middelburg
# Processing Record 31 of Set 9 | mermoz boabab
# Processing Record 32 of Set 9 | jincheng
# Processing Record 33 of Set 9 | murun-kuren
# Processing Record 34 of Set 9 | shenjiamen
# Processing Record 35 of Set 9 | devinuwara
# City not found. Skipping...
# Processing Record 36 of Set 9 | melfort
# Processing Record 37 of Set 9 | klyuchi
# Processing Record 38 of Set 9 | scottburgh
# Processing Record 39 of Set 9 | lock haven
# Processing Record 40 of Set 9 | happy valley-goose bay
# Processing Record 41 of Set 9 | borgarnes
# Processing Record 42 of Set 9 | feicheng
# Processing Record 43 of Set 9 | anna regina
# Processing Record 44 of Set 9 | zaozersk
# Processing Record 45 of Set 9 | ouellah
# City not found. Skipping...
# Processing Record 46 of Set 9 | hayma'
# City not found. Skipping...
# Processing Record 47 of Set 9 | codrington
# Processing Record 48 of Set 9 | smara
# Processing Record 49 of Set 9 | litchfield
# Processing Record 0 of Set 10 | aras-asan
# Processing Record 1 of Set 10 | myitkyina
# Processing Record 2 of Set 10 | banda aceh
# Processing Record 3 of Set 10 | san ignacio
# Processing Record 4 of Set 10 | vingt cinq
# City not found. Skipping...
# Processing Record 5 of Set 10 | grevesmuhlen
# Processing Record 6 of Set 10 | gisborne
# Processing Record 7 of Set 10 | nizao
# Processing Record 8 of Set 10 | curillo
# Processing Record 9 of Set 10 | borogontsy
# Processing Record 10 of Set 10 | twon-brass
# Processing Record 11 of Set 10 | mendi
# Processing Record 12 of Set 10 | kone
# Processing Record 13 of Set 10 | puente alto
# Processing Record 14 of Set 10 | wotho
# Processing Record 15 of Set 10 | oskaloosa
# Processing Record 16 of Set 10 | shangmei
# Processing Record 17 of Set 10 | malanje
# Processing Record 18 of Set 10 | isla mujeres
# Processing Record 19 of Set 10 | manoharpur
# Processing Record 20 of Set 10 | sassandra
# Processing Record 21 of Set 10 | zhalantun
# Processing Record 22 of Set 10 | iquitos
# Processing Record 23 of Set 10 | hotan
# Processing Record 24 of Set 10 | nikshahr
# City not found. Skipping...
# Processing Record 25 of Set 10 | dharchula
# Processing Record 26 of Set 10 | wangon
# Processing Record 27 of Set 10 | shagonar
# Processing Record 28 of Set 10 | kailua-kona
# Processing Record 29 of Set 10 | mildura
# Processing Record 30 of Set 10 | richards bay
# Processing Record 31 of Set 10 | hithadhoo
# Processing Record 32 of Set 10 | piti village
# Processing Record 33 of Set 10 | santa marta de tormes
# Processing Record 34 of Set 10 | iwanai
# Processing Record 35 of Set 10 | nizhneudinsk
# Processing Record 36 of Set 10 | jeddah
# Processing Record 37 of Set 10 | mejit
# Processing Record 38 of Set 10 | kourou
# Processing Record 39 of Set 10 | bure
# Processing Record 40 of Set 10 | la possession
# Processing Record 41 of Set 10 | arno
# Processing Record 42 of Set 10 | farafangana
# Processing Record 43 of Set 10 | nuuk
# Processing Record 44 of Set 10 | ciutadella
# Processing Record 45 of Set 10 | ust'-kulom
# Processing Record 46 of Set 10 | pandan
# Processing Record 47 of Set 10 | port douglas
# Processing Record 48 of Set 10 | buckie
# Processing Record 49 of Set 10 | mangaratiba
# Processing Record 0 of Set 11 | tharangambadi
# Processing Record 1 of Set 11 | sisimiut
# Processing Record 2 of Set 11 | rajura
# Processing Record 3 of Set 11 | berryville
# Processing Record 4 of Set 11 | bardai
# Processing Record 5 of Set 11 | san juan bautista
# Processing Record 6 of Set 11 | pul-e khumri
# Processing Record 7 of Set 11 | beardstown
# Processing Record 8 of Set 11 | bunia
# Processing Record 9 of Set 11 | abraham's bay
# City not found. Skipping...
# Processing Record 10 of Set 11 | swanzey
# Processing Record 11 of Set 11 | acapulco de juarez
# Processing Record 12 of Set 11 | vejer de la frontera
# Processing Record 13 of Set 11 | crixas
# Processing Record 14 of Set 11 | tropea
# Processing Record 15 of Set 11 | watseka
# Processing Record 16 of Set 11 | natal
# Processing Record 17 of Set 11 | dame-marie
# Processing Record 18 of Set 11 | salinopolis
# Processing Record 19 of Set 11 | barrow in furness
# Processing Record 20 of Set 11 | rocky mountain house
# Processing Record 21 of Set 11 | jumla
# Processing Record 22 of Set 11 | jijel
# Processing Record 23 of Set 11 | camana
# Processing Record 24 of Set 11 | butte
# Processing Record 25 of Set 11 | huarmey
# Processing Record 26 of Set 11 | tofol
# Processing Record 27 of Set 11 | valparaiso
# Processing Record 28 of Set 11 | zangguy
# City not found. Skipping...
# Processing Record 29 of Set 11 | montagu
# Processing Record 30 of Set 11 | okahao
# Processing Record 31 of Set 11 | mount gambier
# Processing Record 32 of Set 11 | cadca
# Processing Record 33 of Set 11 | kholmsk
# Processing Record 34 of Set 11 | macapa
# Processing Record 35 of Set 11 | fort stockton
# Processing Record 36 of Set 11 | montepuez
# Processing Record 37 of Set 11 | lodwar
# Processing Record 38 of Set 11 | funafuti
# Processing Record 39 of Set 11 | griffith
# Processing Record 40 of Set 11 | linton hall
# Processing Record 41 of Set 11 | yagry
# City not found. Skipping...
# Processing Record 42 of Set 11 | degerfors
# Processing Record 43 of Set 11 | gislaved
# Processing Record 44 of Set 11 | tongouson
# Processing Record 45 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 46 of Set 11 | kokopo
# Processing Record 47 of Set 11 | itapirapua
# Processing Record 48 of Set 11 | tafuna
# Processing Record 49 of Set 11 | sovetskaya gavan'
# Processing Record 0 of Set 12 | salym
# Processing Record 1 of Set 12 | kashgar
# Processing Record 2 of Set 12 | malvan
# Processing Record 3 of Set 12 | general mosconi
# Processing Record 4 of Set 12 | volchikha
# Processing Record 5 of Set 12 | yamba
# Processing Record 6 of Set 12 | extrema
# Processing Record 7 of Set 12 | williams lake
# Processing Record 8 of Set 12 | nemuro
# Processing Record 9 of Set 12 | santa elena de uairen
# Processing Record 10 of Set 12 | olyokminsk
# Processing Record 11 of Set 12 | kayangel
# Processing Record 12 of Set 12 | cranbrook
# Processing Record 13 of Set 12 | pariaman
# Processing Record 14 of Set 12 | puerto san carlos
# City not found. Skipping...
# Processing Record 15 of Set 12 | thunder bay
# Processing Record 16 of Set 12 | languyan
# Processing Record 17 of Set 12 | sungai penuh
# Processing Record 18 of Set 12 | damongo
# City not found. Skipping...
# Processing Record 19 of Set 12 | raja
# Processing Record 20 of Set 12 | chegdomyn
# Processing Record 21 of Set 12 | okuchi-shinohara
# Processing Record 22 of Set 12 | lewistown
# Processing Record 23 of Set 12 | initao
# Processing Record 24 of Set 12 | sinan
# Processing Record 25 of Set 12 | sal rei
# Processing Record 26 of Set 12 | tres arroyos
# Processing Record 27 of Set 12 | moapa valley
# Processing Record 28 of Set 12 | queenstown
# Processing Record 29 of Set 12 | yarmouth
# Processing Record 30 of Set 12 | yeraliyev
# Processing Record 31 of Set 12 | balabac
# Processing Record 32 of Set 12 | santander
# Processing Record 33 of Set 12 | barra de santo antonio
# Processing Record 34 of Set 12 | mitu
# Processing Record 35 of Set 12 | ko lanta
# Processing Record 36 of Set 12 | toungo
# Processing Record 37 of Set 12 | port saint john's
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          560
# Lat           560
# Lng           560
# Max Temp      560
# Humidity      560
# Cloudiness    560
# Wind Speed    560
# Country       560
# Date          560
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  praia da vitoria  38.7333  -27.0667     22.14        73          40
# 1         grytviken -54.2811  -36.5092     -2.51        83          18
# 2         adamstown -25.0660 -130.1015     22.58        82          63
# 3        san felipe  10.3399  -68.7425     34.57        38          21
# 4            lander  42.8330 -108.7307     20.62        52           0
#
#    Wind Speed Country                Date
# 0        4.14      PT 2024-06-08 09:18:43
# 1        2.72      GS 2024-06-08 09:18:43
# 2        4.66      PN 2024-06-08 09:18:43
# 3        3.11      VE 2024-06-08 09:18:43
# 4        2.57      US 2024-06-08 09:18:43

# %%
# Export the City_Data into a csv
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir) 
data_dir = os.path.join(parent_dir, "output_data")

file_path = os.path.join(data_dir, 'cities.csv')

city_data_df.to_csv(file_path, index=False)


print(f"CSV file saved to: {file_path}")
# Out:
# CSV file saved to: /Users/wenlirui/Desktop/Starter_Code-4/output_data/cities.csv

# %%
# Read saved data
city_to_load = os.path.join(parent_dir, "output_data", "cities.csv")
city_data_df = pd.read_csv(city_to_load)


# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  praia da vitoria  38.7333  -27.0667     22.14        73          40
# 1         grytviken -54.2811  -36.5092     -2.51        83          18
# 2         adamstown -25.0660 -130.1015     22.58        82          63
# 3        san felipe  10.3399  -68.7425     34.57        38          21
# 4            lander  42.8330 -108.7307     20.62        52           0
#
#    Wind Speed Country                 Date
# 0        4.14      PT  2024-06-08 09:18:43
# 1        2.72      GS  2024-06-08 09:18:43
# 2        4.66      PN  2024-06-08 09:18:43
# 3        3.11      VE  2024-06-08 09:18:43
# 4        2.57      US  2024-06-08 09:18:43

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
today = time.strftime("%m/%d/%Y")
# YOUR CODE HERE
plt.scatter(pd.to_numeric(city_data_df["Lat"]).astype(float), pd.to_numeric(city_data_df["Max Temp"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs Max Temperature {today}")
print("The plot proves that as we generally move away from the equator, temperature drops")
# Save the figure
plt.savefig(data_dir+"Fig1.png")

# Show plot
plt.show()
# Out:
# The plot proves that as we generally move away from the equator, temperature drops

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE
plt.scatter(pd.to_numeric(city_data_df["Lat"]).astype(float), pd.to_numeric(city_data_df["Humidity"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs Humidity (%) {today}")
print("The plot shows that there is no real pattern that can describe the relationship between latitude and humidity")
# Save the figure
plt.savefig(data_dir+"Fig2.png")

# Show plot
plt.show()
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and humidity

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
plt.scatter(pd.to_numeric(weather_df["Lat"]).astype(float), pd.to_numeric(weather_df["Cloudiness"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs Cloudiness ({today})")
print("The plot shows that there is no real pattern that can describe the relationship between latitude and cloudiness")
# Save the figure
plt.savefig(data_dir+"Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig(data_dir+"Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.7161472181434118

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
